# %%
import matplotlib.pyplot as plt 
matplotlib.pyplot.plot(*args,scalex=True,scaley=True,data=None,**kwargs)
# Out:
#   File "<ipython-input-1-fb4cdc9bceb5>", line 1
#     import matplotlib.pyplot as plt
#                                    ^
# SyntaxError: invalid character in identifier

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x, y,)
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x, y, 'go-', label='line 1', linewidth=2)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(10)

plt.plot(x,x*1.5,'go:',x,x*2.5,'rx',x,x*3.5,'^',x,x*4.5,'bd-.')
# Out:
# [<matplotlib.lines.Line2D at 0x258515e8430>,
#  <matplotlib.lines.Line2D at 0x258515e84c0>,
#  <matplotlib.lines.Line2D at 0x258515e83d0>,
#  <matplotlib.lines.Line2D at 0x258515e84f0>]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
 
fig, axes = plt.subplots(2, 2) # 建立 2*2 多維視窗 
data = pd.Series(np.random.rand(5), index=list('12345'))

             #ax為選擇畫圖視窗，color為顏色，alpha為透明度設定    
data.plot.bar(ax=axes[0,1], color='b', alpha = 1) 
data.plot.barh(ax=axes[1,1], color='b', alpha=0.5)
data.plot.bar(ax=axes[1,0], color='c', alpha = 0.8) 
data.plot.barh(ax=axes[0,0], color='r', alpha=0.5)
 
plt.show()

# %%
X = np.random.normal(0, 1, 100)
Y = np.random.normal(0, 1, 100)
plt.scatter(X, Y, color='b',alpha=0.5,s=100,edgecolors='red')
plt.title("Scatter plot ")
# Out:
# Text(0.5, 1.0, 'Scatter plot ')

# %%
x = np.arange(0., 10., 0.7)
y = np.arange(0., 10., 0.7)

plt.bar(x, y)
# Out:
# <BarContainer object of 15 artists>

# %%
#hw1
import  numpy as np
import matplotlib.pyplot as plt
#劃出sin波從0-180度
x = np.arange(0,180)
y = np.cos(x*np.pi/180)
plt.plot(x,y,)
plt.show()

# %%
#劃出sin圖形
x = np.arange(0, 3*np.pi, 0.1)
y_sin = np.sin(x)
plt.plot(x,y_sin)

# %%
#劃出cos圖形
x = np.arange(0, 3*np.pi, 0.1)
y_cos = np.cos(x)
plt.plot(x,y_cos)

# %%
#hw2
n = 1024
X = np.random.normal(0,1,n)
Y = np.random.normal(0,1,n)

T = np.arctan2(Y, X)
plt.scatter(X, Y, s=75, c=T, alpha=0.5)

plt.xlim(-1.5,1.5)
plt.ylim(-1.5,1.5)

plt.show()

# %%
T
# Out:
# array([-2.29762733,  2.82454913, -2.99088014, ...,  1.29893271,
#        -3.05681797, -0.88781966])

# %%
#進階題hw1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#要先匯入

df.boxplot(figsize=(15, 10))
df.scatterplot(x='NOX', y='DIS')
